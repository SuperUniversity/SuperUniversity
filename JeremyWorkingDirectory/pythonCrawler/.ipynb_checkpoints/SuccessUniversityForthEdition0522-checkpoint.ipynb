# %%
import requests
import re
from bs4 import BeautifulSoup

path = 'http://course-query.acad.ncku.edu.tw/qry/'                                                         ##Courses classification Main Webform
r = requests.get(path)
r.encoding = 'utf8'
html_doc = r.text
soup = BeautifulSoup(html_doc, 'lxml')


def name_a_has_target(tag):
    return tag.has_attr('target') and tag.name == 'a'
LinkList = []

def FindSchool(tag):
    return tag.name == 'div' and tag['class'] == ['theader']


#find first link
KeyTag = soup.find(href = re.compile('dept_no=A2'))     ##Search 'dept_no=A2', Get Tag including first-wanted link, and name it KeyTag
LnkDict = {'link': str('http://course-query.acad.ncku.edu.tw/qry/' + str(KeyTag['href'])), 
           'School': str(KeyTag.find_previous(FindSchool).string) }
LinkList.append(LnkDict)


#find all next links
count = 0
for item in KeyTag.find_all_next(name_a_has_target):
    LnkDict = {'link': str('http://course-query.acad.ncku.edu.tw/qry/' + str(item['href'])), 
               'School': str(item.find_previous(FindSchool).string) }
    LinkList.append(LnkDict)
#     print(LnkDict)
    print('link%a success ' %(count))
    count +=1
# Out:
# {'link': 'http://course-query.acad.ncku.edu.tw/qry/qry001.php?dept_no=A3', 'School': '其他'}
# link0 success
# {'link': 'http://course-query.acad.ncku.edu.tw/qry/qry001.php?dept_no=A4', 'School': '其他'}
# link1 success
# {'link': 'http://course-query.acad.ncku.edu.tw/qry/qry001.php?dept_no=A5', 'School': '其他'}
# link2 success
# {'link': 'http://course-query.acad.ncku.edu.tw/qry/qry001.php?dept_no=A6', 'School': '其他'}
# link3 success
# {'link': 'http://course-query.acad.ncku.edu.tw/qry/qry001.php?dept_no=AA', 'School': '其他'}
# link4 success
# {'link': 'http://course-query.acad.ncku.edu.tw/qry/qry001.php?dept_no=AH', 'School': '其他'}
# link5 success
# {'link': 'http://course-query.acad.ncku.edu.tw/qry/qry001.php?dept_no=AN', 'School': '不分學院'}
# link6 success
# {'link': 'http://course-query.acad.ncku.edu.tw/qry/qry001.php?dept_no=C0', 'School': '不分學院'}
# link7 success
# {'link': 'http://course-query.acad.ncku.edu.tw/qry/qry001.php?dept_no=A1', 'School': '通識課程'}
# link8 success
# {'link': 'http://course-query.acad.ncku.edu.tw/qry/qry001.php?dept_no=A7', 'School': '通識課程'}
# link9 success
# {'link': 'http://course-query.acad.ncku.edu.tw/qry/qry001.php?dept_no=A9', 'School': '通識課程'}
# link10 success
# {'link': 'http://course-query.acad.ncku.edu.tw/qry/qry001.php?dept_no=AG', 'School': '通識課程'}
# link11 success
# {'link': 'http://course-query.acad.ncku.edu.tw/qry/qry001.php?dept_no=B0', 'School': '文學院'}
# link12 success
# {'link': 'http://course-query.acad.ncku.edu.tw/qry/qry001.php?dept_no=B1', 'School': '文學院'}
# link13 success
# {'link': 'http://course-query.acad.ncku.edu.tw/qry/qry001.php?dept_no=K1', 'School': '文學院'}
# link14 success
# {'link': 'http://course-query.acad.ncku.edu.tw/qry/qry001.php?dept_no=B2', 'School': '文學院'}
# link15 success
# {'link': 'http://course-query.acad.ncku.edu.tw/qry/qry001.php?dept_no=K2', 'School': '文學院'}
# link16 success
# {'link': 'http://course-query.acad.ncku.edu.tw/qry/qry001.php?dept_no=B3', 'School': '文學院'}
# link17 success
# {'link': 'http://course-query.acad.ncku.edu.tw/qry/qry001.php?dept_no=K3', 'School': '文學院'}
# link18 success
# {'link': 'http://course-query.acad.ncku.edu.tw/qry/qry001.php?dept_no=B5', 'School': '文學院'}
# link19 success
# {'link': 'http://course-query.acad.ncku.edu.tw/qry/qry001.php?dept_no=K5', 'School': '文學院'}
# link20 success
# {'link': 'http://course-query.acad.ncku.edu.tw/qry/qry001.php?dept_no=K4', 'School': '文學院'}
# link21 success
# {'link': 'http://course-query.acad.ncku.edu.tw/qry/qry001.php?dept_no=K7', 'School': '文學院'}
# link22 success
# {'link': 'http://course-query.acad.ncku.edu.tw/qry/qry001.php?dept_no=K8', 'School': '文學院'}
# link23 success
# {'link': 'http://course-query.acad.ncku.edu.tw/qry/qry001.php?dept_no=C1', 'School': '理學院'}
# link24 success
# {'link': 'http://course-query.acad.ncku.edu.tw/qry/qry001.php?dept_no=L1', 'School': '理學院'}
# link25 success
# {'link': 'http://course-query.acad.ncku.edu.tw/qry/qry001.php?dept_no=C2', 'School': '理學院'}
# link26 success
# {'link': 'http://course-query.acad.ncku.edu.tw/qry/qry001.php?dept_no=L2', 'School': '理學院'}
# link27 success
# {'link': 'http://course-query.acad.ncku.edu.tw/qry/qry001.php?dept_no=C3', 'School': '理學院'}
# link28 success
# {'link': 'http://course-query.acad.ncku.edu.tw/qry/qry001.php?dept_no=L3', 'School': '理學院'}
# link29 success
# {'link': 'http://course-query.acad.ncku.edu.tw/qry/qry001.php?dept_no=C4', 'School': '理學院'}
# link30 success
# {'link': 'http://course-query.acad.ncku.edu.tw/qry/qry001.php?dept_no=L4', 'School': '理學院'}
# link31 success
# {'link': 'http://course-query.acad.ncku.edu.tw/qry/qry001.php?dept_no=CZ', 'School': '理學院'}
# link32 success
# {'link': 'http://course-query.acad.ncku.edu.tw/qry/qry001.php?dept_no=F8', 'School': '理學院'}
# link33 success
# {'link': 'http://course-query.acad.ncku.edu.tw/qry/qry001.php?dept_no=L7', 'School': '理學院'}
# link34 success
# {'link': 'http://course-query.acad.ncku.edu.tw/qry/qry001.php?dept_no=LA', 'School': '理學院'}
# link35 success
# {'link': 'http://course-query.acad.ncku.edu.tw/qry/qry001.php?dept_no=VF', 'School': '理學院'}
# link36 success
# {'link': 'http://course-query.acad.ncku.edu.tw/qry/qry001.php?dept_no=E0', 'School': '工學院'}
# link37 success
# {'link': 'http://course-query.acad.ncku.edu.tw/qry/qry001.php?dept_no=E1', 'School': '工學院'}
# link38 success
# {'link': 'http://course-query.acad.ncku.edu.tw/qry/qry001.php?dept_no=N1', 'School': '工學院'}
# link39 success
# {'link': 'http://course-query.acad.ncku.edu.tw/qry/qry001.php?dept_no=E3', 'School': '工學院'}
# link40 success
# {'link': 'http://course-query.acad.ncku.edu.tw/qry/qry001.php?dept_no=N3', 'School': '工學院'}
# link41 success
# {'link': 'http://course-query.acad.ncku.edu.tw/qry/qry001.php?dept_no=E4', 'School': '工學院'}
# link42 success
# {'link': 'http://course-query.acad.ncku.edu.tw/qry/qry001.php?dept_no=N4', 'School': '工學院'}
# link43 success
# {'link': 'http://course-query.acad.ncku.edu.tw/qry/qry001.php?dept_no=E5', 'School': '工學院'}
# link44 success
# {'link': 'http://course-query.acad.ncku.edu.tw/qry/qry001.php?dept_no=N5', 'School': '工學院'}
# link45 success
# {'link': 'http://course-query.acad.ncku.edu.tw/qry/qry001.php?dept_no=E6', 'School': '工學院'}
# link46 success
# {'link': 'http://course-query.acad.ncku.edu.tw/qry/qry001.php?dept_no=N6', 'School': '工學院'}
# link47 success
# {'link': 'http://course-query.acad.ncku.edu.tw/qry/qry001.php?dept_no=E8', 'School': '工學院'}
# link48 success
# {'link': 'http://course-query.acad.ncku.edu.tw/qry/qry001.php?dept_no=N8', 'School': '工學院'}
# link49 success
# {'link': 'http://course-query.acad.ncku.edu.tw/qry/qry001.php?dept_no=NC', 'School': '工學院'}
# link50 success
# {'link': 'http://course-query.acad.ncku.edu.tw/qry/qry001.php?dept_no=E9', 'School': '工學院'}
# link51 success
# {'link': 'http://course-query.acad.ncku.edu.tw/qry/qry001.php?dept_no=N9', 'School': '工學院'}
# link52 success
# {'link': 'http://course-query.acad.ncku.edu.tw/qry/qry001.php?dept_no=F0', 'School': '工學院'}
# link53 success
# {'link': 'http://course-query.acad.ncku.edu.tw/qry/qry001.php?dept_no=P0', 'School': '工學院'}
# link54 success
# {'link': 'http://course-query.acad.ncku.edu.tw/qry/qry001.php?dept_no=F1', 'School': '工學院'}
# link55 success
# {'link': 'http://course-query.acad.ncku.edu.tw/qry/qry001.php?dept_no=P1', 'School': '工學院'}
# link56 success
# {'link': 'http://course-query.acad.ncku.edu.tw/qry/qry001.php?dept_no=F4', 'School': '工學院'}
# link57 success
# {'link': 'http://course-query.acad.ncku.edu.tw/qry/qry001.php?dept_no=P4', 'School': '工學院'}
# link58 success
# {'link': 'http://course-query.acad.ncku.edu.tw/qry/qry001.php?dept_no=Q4', 'School': '工學院'}
# link59 success
# {'link': 'http://course-query.acad.ncku.edu.tw/qry/qry001.php?dept_no=F5', 'School': '工學院'}
# link60 success
# {'link': 'http://course-query.acad.ncku.edu.tw/qry/qry001.php?dept_no=P5', 'School': '工學院'}
# link61 success
# {'link': 'http://course-query.acad.ncku.edu.tw/qry/qry001.php?dept_no=F6', 'School': '工學院'}
# link62 success
# {'link': 'http://course-query.acad.ncku.edu.tw/qry/qry001.php?dept_no=P6', 'School': '工學院'}
# link63 success
# {'link': 'http://course-query.acad.ncku.edu.tw/qry/qry001.php?dept_no=F9', 'School': '工學院'}
# link64 success
# {'link': 'http://course-query.acad.ncku.edu.tw/qry/qry001.php?dept_no=P8', 'School': '工學院'}
# link65 success
# {'link': 'http://course-query.acad.ncku.edu.tw/qry/qry001.php?dept_no=N0', 'School': '工學院'}
# link66 success
# {'link': 'http://course-query.acad.ncku.edu.tw/qry/qry001.php?dept_no=NA', 'School': '工學院'}
# link67 success
# {'link': 'http://course-query.acad.ncku.edu.tw/qry/qry001.php?dept_no=NB', 'School': '工學院'}
# link68 success
# {'link': 'http://course-query.acad.ncku.edu.tw/qry/qry001.php?dept_no=H1', 'School': '管理學院'}
# link69 success
# {'link': 'http://course-query.acad.ncku.edu.tw/qry/qry001.php?dept_no=R1', 'School': '管理學院'}
# link70 success
# {'link': 'http://course-query.acad.ncku.edu.tw/qry/qry001.php?dept_no=H2', 'School': '管理學院'}
# link71 success
# {'link': 'http://course-query.acad.ncku.edu.tw/qry/qry001.php?dept_no=R2', 'School': '管理學院'}
# link72 success
# {'link': 'http://course-query.acad.ncku.edu.tw/qry/qry001.php?dept_no=H3', 'School': '管理學院'}
# link73 success
# {'link': 'http://course-query.acad.ncku.edu.tw/qry/qry001.php?dept_no=R3', 'School': '管理學院'}
# link74 success
# {'link': 'http://course-query.acad.ncku.edu.tw/qry/qry001.php?dept_no=R7', 'School': '管理學院'}
# link75 success
# {'link': 'http://course-query.acad.ncku.edu.tw/qry/qry001.php?dept_no=H4', 'School': '管理學院'}
# link76 success
# {'link': 'http://course-query.acad.ncku.edu.tw/qry/qry001.php?dept_no=R4', 'School': '管理學院'}
# link77 success
# {'link': 'http://course-query.acad.ncku.edu.tw/qry/qry001.php?dept_no=H5', 'School': '管理學院'}
# link78 success
# {'link': 'http://course-query.acad.ncku.edu.tw/qry/qry001.php?dept_no=R5', 'School': '管理學院'}
# link79 success
# {'link': 'http://course-query.acad.ncku.edu.tw/qry/qry001.php?dept_no=R9', 'School': '管理學院'}
# link80 success
# {'link': 'http://course-query.acad.ncku.edu.tw/qry/qry001.php?dept_no=R0', 'School': '管理學院'}
# link81 success
# {'link': 'http://course-query.acad.ncku.edu.tw/qry/qry001.php?dept_no=R6', 'School': '管理學院'}
# link82 success
# {'link': 'http://course-query.acad.ncku.edu.tw/qry/qry001.php?dept_no=R8', 'School': '管理學院'}
# link83 success
# {'link': 'http://course-query.acad.ncku.edu.tw/qry/qry001.php?dept_no=RA', 'School': '管理學院'}
# link84 success
# {'link': 'http://course-query.acad.ncku.edu.tw/qry/qry001.php?dept_no=RB', 'School': '管理學院'}
# link85 success
# {'link': 'http://course-query.acad.ncku.edu.tw/qry/qry001.php?dept_no=RD', 'School': '管理學院'}
# link86 success
# {'link': 'http://course-query.acad.ncku.edu.tw/qry/qry001.php?dept_no=RZ', 'School': '管理學院'}
# link87 success
# {'link': 'http://course-query.acad.ncku.edu.tw/qry/qry001.php?dept_no=I2', 'School': '醫學院'}
# link88 success
# {'link': 'http://course-query.acad.ncku.edu.tw/qry/qry001.php?dept_no=T2', 'School': '醫學院'}
# link89 success
# {'link': 'http://course-query.acad.ncku.edu.tw/qry/qry001.php?dept_no=I3', 'School': '醫學院'}
# link90 success
# {'link': 'http://course-query.acad.ncku.edu.tw/qry/qry001.php?dept_no=T3', 'School': '醫學院'}
# link91 success
# {'link': 'http://course-query.acad.ncku.edu.tw/qry/qry001.php?dept_no=I5', 'School': '醫學院'}
# link92 success
# {'link': 'http://course-query.acad.ncku.edu.tw/qry/qry001.php?dept_no=I6', 'School': '醫學院'}
# link93 success
# {'link': 'http://course-query.acad.ncku.edu.tw/qry/qry001.php?dept_no=T6', 'School': '醫學院'}
# link94 success
# {'link': 'http://course-query.acad.ncku.edu.tw/qry/qry001.php?dept_no=I7', 'School': '醫學院'}
# link95 success
# {'link': 'http://course-query.acad.ncku.edu.tw/qry/qry001.php?dept_no=T7', 'School': '醫學院'}
# link96 success
# {'link': 'http://course-query.acad.ncku.edu.tw/qry/qry001.php?dept_no=I8', 'School': '醫學院'}
# link97 success
# {'link': 'http://course-query.acad.ncku.edu.tw/qry/qry001.php?dept_no=S0', 'School': '醫學院'}
# link98 success
# {'link': 'http://course-query.acad.ncku.edu.tw/qry/qry001.php?dept_no=S1', 'School': '醫學院'}
# link99 success
# {'link': 'http://course-query.acad.ncku.edu.tw/qry/qry001.php?dept_no=S2', 'School': '醫學院'}
# link100 success
# {'link': 'http://course-query.acad.ncku.edu.tw/qry/qry001.php?dept_no=S3', 'School': '醫學院'}
# link101 success
# {'link': 'http://course-query.acad.ncku.edu.tw/qry/qry001.php?dept_no=S4', 'School': '醫學院'}
# link102 success
# {'link': 'http://course-query.acad.ncku.edu.tw/qry/qry001.php?dept_no=S5', 'School': '醫學院'}
# link103 success
# {'link': 'http://course-query.acad.ncku.edu.tw/qry/qry001.php?dept_no=S6', 'School': '醫學院'}
# link104 success
# {'link': 'http://course-query.acad.ncku.edu.tw/qry/qry001.php?dept_no=S7', 'School': '醫學院'}
# link105 success
# {'link': 'http://course-query.acad.ncku.edu.tw/qry/qry001.php?dept_no=S8', 'School': '醫學院'}
# link106 success
# {'link': 'http://course-query.acad.ncku.edu.tw/qry/qry001.php?dept_no=S9', 'School': '醫學院'}
# link107 success
# {'link': 'http://course-query.acad.ncku.edu.tw/qry/qry001.php?dept_no=SA', 'School': '醫學院'}
# link108 success
# {'link': 'http://course-query.acad.ncku.edu.tw/qry/qry001.php?dept_no=SB', 'School': '醫學院'}
# link109 success
# {'link': 'http://course-query.acad.ncku.edu.tw/qry/qry001.php?dept_no=SC', 'School': '醫學院'}
# link110 success
# {'link': 'http://course-query.acad.ncku.edu.tw/qry/qry001.php?dept_no=T1', 'School': '醫學院'}
# link111 success
# {'link': 'http://course-query.acad.ncku.edu.tw/qry/qry001.php?dept_no=T4', 'School': '醫學院'}
# link112 success
# {'link': 'http://course-query.acad.ncku.edu.tw/qry/qry001.php?dept_no=T8', 'School': '醫學院'}
# link113 success
# {'link': 'http://course-query.acad.ncku.edu.tw/qry/qry001.php?dept_no=T9', 'School': '醫學院'}
# link114 success
# {'link': 'http://course-query.acad.ncku.edu.tw/qry/qry001.php?dept_no=TA', 'School': '醫學院'}
# link115 success
# {'link': 'http://course-query.acad.ncku.edu.tw/qry/qry001.php?dept_no=TC', 'School': '醫學院'}
# link116 success
# {'link': 'http://course-query.acad.ncku.edu.tw/qry/qry001.php?dept_no=D2', 'School': '社會科學院'}
# link117 success
# {'link': 'http://course-query.acad.ncku.edu.tw/qry/qry001.php?dept_no=U2', 'School': '社會科學院'}
# link118 success
# {'link': 'http://course-query.acad.ncku.edu.tw/qry/qry001.php?dept_no=D4', 'School': '社會科學院'}
# link119 success
# {'link': 'http://course-query.acad.ncku.edu.tw/qry/qry001.php?dept_no=D5', 'School': '社會科學院'}
# link120 success
# {'link': 'http://course-query.acad.ncku.edu.tw/qry/qry001.php?dept_no=U5', 'School': '社會科學院'}
# link121 success
# {'link': 'http://course-query.acad.ncku.edu.tw/qry/qry001.php?dept_no=D8', 'School': '社會科學院'}
# link122 success
# {'link': 'http://course-query.acad.ncku.edu.tw/qry/qry001.php?dept_no=U7', 'School': '社會科學院'}
# link123 success
# {'link': 'http://course-query.acad.ncku.edu.tw/qry/qry001.php?dept_no=U1', 'School': '社會科學院'}
# link124 success
# {'link': 'http://course-query.acad.ncku.edu.tw/qry/qry001.php?dept_no=U3', 'School': '社會科學院'}
# link125 success
# {'link': 'http://course-query.acad.ncku.edu.tw/qry/qry001.php?dept_no=E2', 'School': '電機資訊學院'}
# link126 success
# {'link': 'http://course-query.acad.ncku.edu.tw/qry/qry001.php?dept_no=N2', 'School': '電機資訊學院'}
# link127 success
# {'link': 'http://course-query.acad.ncku.edu.tw/qry/qry001.php?dept_no=Q1', 'School': '電機資訊學院'}
# link128 success
# {'link': 'http://course-query.acad.ncku.edu.tw/qry/qry001.php?dept_no=Q3', 'School': '電機資訊學院'}
# link129 success
# {'link': 'http://course-query.acad.ncku.edu.tw/qry/qry001.php?dept_no=Q6', 'School': '電機資訊學院'}
# link130 success
# {'link': 'http://course-query.acad.ncku.edu.tw/qry/qry001.php?dept_no=Q7', 'School': '電機資訊學院'}
# link131 success
# {'link': 'http://course-query.acad.ncku.edu.tw/qry/qry001.php?dept_no=F7', 'School': '電機資訊學院'}
# link132 success
# {'link': 'http://course-query.acad.ncku.edu.tw/qry/qry001.php?dept_no=ND', 'School': '電機資訊學院'}
# link133 success
# {'link': 'http://course-query.acad.ncku.edu.tw/qry/qry001.php?dept_no=P7', 'School': '電機資訊學院'}
# link134 success
# {'link': 'http://course-query.acad.ncku.edu.tw/qry/qry001.php?dept_no=Q5', 'School': '電機資訊學院'}
# link135 success
# {'link': 'http://course-query.acad.ncku.edu.tw/qry/qry001.php?dept_no=P9', 'School': '電機資訊學院'}
# link136 success
# {'link': 'http://course-query.acad.ncku.edu.tw/qry/qry001.php?dept_no=V6', 'School': '電機資訊學院'}
# link137 success
# {'link': 'http://course-query.acad.ncku.edu.tw/qry/qry001.php?dept_no=V8', 'School': '電機資訊學院'}
# link138 success
# {'link': 'http://course-query.acad.ncku.edu.tw/qry/qry001.php?dept_no=V9', 'School': '電機資訊學院'}
# link139 success
# {'link': 'http://course-query.acad.ncku.edu.tw/qry/qry001.php?dept_no=VA', 'School': '電機資訊學院'}
# link140 success
# {'link': 'http://course-query.acad.ncku.edu.tw/qry/qry001.php?dept_no=VB', 'School': '電機資訊學院'}
# link141 success
# {'link': 'http://course-query.acad.ncku.edu.tw/qry/qry001.php?dept_no=VC', 'School': '電機資訊學院'}
# link142 success
# {'link': 'http://course-query.acad.ncku.edu.tw/qry/qry001.php?dept_no=VD', 'School': '電機資訊學院'}
# link143 success
# {'link': 'http://course-query.acad.ncku.edu.tw/qry/qry001.php?dept_no=VE', 'School': '電機資訊學院'}
# link144 success
# {'link': 'http://course-query.acad.ncku.edu.tw/qry/qry001.php?dept_no=VG', 'School': '電機資訊學院'}
# link145 success
# {'link': 'http://course-query.acad.ncku.edu.tw/qry/qry001.php?dept_no=VH', 'School': '電機資訊學院'}
# link146 success
# {'link': 'http://course-query.acad.ncku.edu.tw/qry/qry001.php?dept_no=VJ', 'School': '電機資訊學院'}
# link147 success
# {'link': 'http://course-query.acad.ncku.edu.tw/qry/qry001.php?dept_no=VK', 'School': '電機資訊學院'}
# link148 success
# {'link': 'http://course-query.acad.ncku.edu.tw/qry/qry001.php?dept_no=VL', 'School': '電機資訊學院'}
# link149 success
# {'link': 'http://course-query.acad.ncku.edu.tw/qry/qry001.php?dept_no=VM', 'School': '電機資訊學院'}
# link150 success
# {'link': 'http://course-query.acad.ncku.edu.tw/qry/qry001.php?dept_no=VN', 'School': '電機資訊學院'}
# link151 success
# {'link': 'http://course-query.acad.ncku.edu.tw/qry/qry001.php?dept_no=E7', 'School': '規劃與設計學院'}
# link152 success
# {'link': 'http://course-query.acad.ncku.edu.tw/qry/qry001.php?dept_no=N7', 'School': '規劃與設計學院'}
# link153 success
# {'link': 'http://course-query.acad.ncku.edu.tw/qry/qry001.php?dept_no=F2', 'School': '規劃與設計學院'}
# link154 success
# {'link': 'http://course-query.acad.ncku.edu.tw/qry/qry001.php?dept_no=P2', 'School': '規劃與設計學院'}
# link155 success
# {'link': 'http://course-query.acad.ncku.edu.tw/qry/qry001.php?dept_no=F3', 'School': '規劃與設計學院'}
# link156 success
# {'link': 'http://course-query.acad.ncku.edu.tw/qry/qry001.php?dept_no=P3', 'School': '規劃與設計學院'}
# link157 success
# {'link': 'http://course-query.acad.ncku.edu.tw/qry/qry001.php?dept_no=PA', 'School': '規劃與設計學院'}
# link158 success
# {'link': 'http://course-query.acad.ncku.edu.tw/qry/qry001.php?dept_no=PB', 'School': '規劃與設計學院'}
# link159 success
# {'link': 'http://course-query.acad.ncku.edu.tw/qry/qry001.php?dept_no=C5', 'School': '生物科學與科技學院'}
# link160 success
# {'link': 'http://course-query.acad.ncku.edu.tw/qry/qry001.php?dept_no=L5', 'School': '生物科學與科技學院'}
# link161 success
# {'link': 'http://course-query.acad.ncku.edu.tw/qry/qry001.php?dept_no=C6', 'School': '生物科學與科技學院'}
# link162 success
# {'link': 'http://course-query.acad.ncku.edu.tw/qry/qry001.php?dept_no=L6', 'School': '生物科學與科技學院'}
# link163 success
# {'link': 'http://course-query.acad.ncku.edu.tw/qry/qry001.php?dept_no=Z0', 'School': '生物科學與科技學院'}
# link164 success
# {'link': 'http://course-query.acad.ncku.edu.tw/qry/qry001.php?dept_no=Z2', 'School': '生物科學與科技學院'}
# link165 success
# {'link': 'http://course-query.acad.ncku.edu.tw/qry/qry001.php?dept_no=Z3', 'School': '生物科學與科技學院'}
# link166 success
# {'link': 'http://course-query.acad.ncku.edu.tw/qry/qry001.php?dept_no=Z5', 'School': '生物科學與科技學院'}
# link167 success

# %%
links = []
for di in LinkList:
    links.append(di['link'])

# %%
for link in enumerate(links):
    file = open('SuccessCourses/'+ str(link[0]), 'w', encoding='utf8')
    r = requests.get(link[1])
    r.encoding = 'utf8'
    html = r.text
    file.write(html)
    file.close()

# %%
import pandas as pd

def WriteHtmlIntoMongo(pahtLi, collection):

    ## Convert Html document to DataFrame, and then to Dictionary List(which can be directly insert into MongoDB)
    def HtmlCoursesInssertMongo(FilePath):
        print(FilePath)
        df_courses = pd.read_html(FilePath ,encoding='utf8')[0]
        df_courses = df_courses.where(df_courses.notnull(), None)
                                                        ##if df_courses.notnull() return true, df_courses = df_courses
                                                        ##else, df_courses=None
                
        ##remove escape char in the column header
        columns = []
        for column in df_courses.columns:
            columns.append(column.replace("(","").replace("*","").replace(":","").replace(")","").replace("連結課程地圖","").replace("主負責老師","").replace(" ",""))
        df_courses.columns = columns
        
        
        ##remove duplicate column header in a lot of Rows
        if len(df_courses[df_courses['系所名稱']=='系所名稱'])>0:
            length = len(df_courses[df_courses['系所名稱']=='系所名稱'])
            for i in range(0,length):
                df_courses.drop(df_courses[df_courses['系所名稱']=='系所名稱'].index[[0]], inplace=True)
                
        if len(df_courses['時間']) > 0:
            ##Replace WeekDay in Chinese
            def ReplaceWeekDay(item):
                if item != None:
                    return item.replace("[1]","一").replace("[2]","二").replace("[3]","三").replace("[4]","四").replace("[5]","五").replace("[6]","六").replace("[7]","日")
#                     return item.replace("[1]","一").replace("[2]","二").replace("[3]","三").replace("[4]","四").replace("[5]","五").replace("[6]","六").replace("[7]","日").replace("~","_")
            df_courses['時間'] = df_courses['時間'].apply(ReplaceWeekDay)
    
        if len(df_courses['教師姓名']) > 0:
            ##Replace TeacherName with special char "*" with "#"
            def ReplaceTeacherName(item):
                if item != None:
                    return item.replace("*","(主),").replace(" ",",")
            df_courses['教師姓名'] = df_courses['教師姓名'].apply(ReplaceTeacherName)
            
#         if len(df_courses['教師姓名']) > 0:
#             ##Replace TeacherName with special char "*" with "#"
#             def ReplaceTeacherName(item):
#                 if item != None:
#                     return item.replace("*","(主),").replace(" ",",")
#             df_courses['教師姓名'] = df_courses['教師姓名'].apply(ReplaceTeacherName)

        
        ##Mongo allow dictionary only. Before transfer to dict, first store it in string type, otherwise, the type in Mongo can be various
        def ToDIct(Row):
            def ToStrAndRemoveSpace(item):
                if(item != None):
                    return str(item).replace(" ","")
                else:
                    return None
            return Row.apply(ToStrAndRemoveSpace).to_dict()
        CoursesDictList = df_courses.apply(ToDIct, axis=1).tolist()
        return CoursesDictList
    
    for path in PathList:
        collection.insert_many(HtmlCoursesInssertMongo(path))


import os
def ConvertToAbsolutePath(filename):
    return 'SuccessCourses/'+filename
PathList = pd.Series(os.listdir('SuccessCourses')).apply(ConvertToAbsolutePath).tolist()

from pymongo import MongoClient
conn = MongoClient('localhost', 27017)
db = conn.SuperUniversityCourses
collection = db['success']

WriteHtmlIntoMongo(PathList, collection)   ##Use function defined above

conn.close()
# Out:
# SuccessCourses/0
# SuccessCourses/1
# SuccessCourses/10
# SuccessCourses/100
# SuccessCourses/101
# SuccessCourses/102
# SuccessCourses/103
# SuccessCourses/104
# SuccessCourses/105
# SuccessCourses/106
# SuccessCourses/107
# SuccessCourses/108
# SuccessCourses/109
# SuccessCourses/11
# SuccessCourses/110
# SuccessCourses/111
# SuccessCourses/112
# SuccessCourses/113
# SuccessCourses/114
# SuccessCourses/115
# SuccessCourses/116
# SuccessCourses/117
# SuccessCourses/118
# SuccessCourses/119
# SuccessCourses/12
# SuccessCourses/120
# SuccessCourses/121
# SuccessCourses/122
# SuccessCourses/123
# SuccessCourses/124
# SuccessCourses/125
# SuccessCourses/126
# SuccessCourses/127
# SuccessCourses/128
# SuccessCourses/129
# SuccessCourses/13
# SuccessCourses/130
# SuccessCourses/131
# SuccessCourses/132
# SuccessCourses/133
# SuccessCourses/134
# SuccessCourses/135
# SuccessCourses/136
# SuccessCourses/137
# SuccessCourses/138
# SuccessCourses/139
# SuccessCourses/14
# SuccessCourses/140
# SuccessCourses/141
# SuccessCourses/142
# SuccessCourses/143
# SuccessCourses/144
# SuccessCourses/145
# SuccessCourses/146
# SuccessCourses/147
# SuccessCourses/148
# SuccessCourses/149
# SuccessCourses/15
# SuccessCourses/150
# SuccessCourses/151
# SuccessCourses/152
# SuccessCourses/153
# SuccessCourses/154
# SuccessCourses/155
# SuccessCourses/156
# SuccessCourses/157
# SuccessCourses/158
# SuccessCourses/159
# SuccessCourses/16
# SuccessCourses/160
# SuccessCourses/161
# SuccessCourses/162
# SuccessCourses/163
# SuccessCourses/164
# SuccessCourses/165
# SuccessCourses/166
# SuccessCourses/167
# SuccessCourses/168
# SuccessCourses/17
# SuccessCourses/18
# SuccessCourses/19
# SuccessCourses/2
# SuccessCourses/20
# SuccessCourses/21
# SuccessCourses/22
# SuccessCourses/23
# SuccessCourses/24
# SuccessCourses/25
# SuccessCourses/26
# SuccessCourses/27
# SuccessCourses/28
# SuccessCourses/29
# SuccessCourses/3
# SuccessCourses/30
# SuccessCourses/31
# SuccessCourses/32
# SuccessCourses/33
# SuccessCourses/34
# SuccessCourses/35
# SuccessCourses/36
# SuccessCourses/37
# SuccessCourses/38
# SuccessCourses/39
# SuccessCourses/4
# SuccessCourses/40
# SuccessCourses/41
# SuccessCourses/42
# SuccessCourses/43
# SuccessCourses/44
# SuccessCourses/45
# SuccessCourses/46
# SuccessCourses/47
# SuccessCourses/48
# SuccessCourses/49
# SuccessCourses/5
# SuccessCourses/50
# SuccessCourses/51
# SuccessCourses/52
# SuccessCourses/53
# SuccessCourses/54
# SuccessCourses/55
# SuccessCourses/56
# SuccessCourses/57
# SuccessCourses/58
# SuccessCourses/59
# SuccessCourses/6
# SuccessCourses/60
# SuccessCourses/61
# SuccessCourses/62
# SuccessCourses/63
# SuccessCourses/64
# SuccessCourses/65
# SuccessCourses/66
# SuccessCourses/67
# SuccessCourses/68
# SuccessCourses/69
# SuccessCourses/7
# SuccessCourses/70
# SuccessCourses/71
# SuccessCourses/72
# SuccessCourses/73
# SuccessCourses/74
# SuccessCourses/75
# SuccessCourses/76
# SuccessCourses/77
# SuccessCourses/78
# SuccessCourses/79
# SuccessCourses/8
# SuccessCourses/80
# SuccessCourses/81
# SuccessCourses/82
# SuccessCourses/83
# SuccessCourses/84
# SuccessCourses/85
# SuccessCourses/86
# SuccessCourses/87
# SuccessCourses/88
# SuccessCourses/89
# SuccessCourses/9
# SuccessCourses/90
# SuccessCourses/91
# SuccessCourses/92
# SuccessCourses/93
# SuccessCourses/94
# SuccessCourses/95
# SuccessCourses/96
# SuccessCourses/97
# SuccessCourses/98
# SuccessCourses/99

# %%
import pandas as pd

df_courses = pd.read_html('SuccessCourses/30' ,encoding='utf8')[0]
df_courses = df_courses.where(df_courses.notnull(), None)

# %%
# df_courses.where(df_courses['系所名稱']=='系所名稱')

# %%
##append new Row

df_courses = df_courses.append(df_courses[df_courses['系所名稱']=='系所名稱'])
# df_courses.append(df_courses[df_courses['系所名稱']=='系所名稱'].to_dict())

# df_courses.drop(df_courses[df_courses['系所名稱']=='系所名稱'].index[[0]])

# %%
# df_courses[df_courses['系所名稱']=='系所名稱'].index[[0]]
for i in range(0,len(df_courses[df_courses['系所名稱']=='系所名稱'])):
    df_courses.drop(df_courses[df_courses['系所名稱']=='系所名稱'].index[[0]], inplace=True)

# %%
# df_courses.describe()
# len(df_courses[df_courses['系所名稱']=='系所名稱'])
df_courses[df_courses['系所名稱']=='系所名稱']
# Out:
# Empty DataFrame
# Columns: [系所名稱, 系號, 序號, 課程碼, 分班碼, 班別, 年級, 類別, 組別, 英語授課, 課程名稱(連結課程地圖), 選必修, 學分, 教師姓名*:主負責老師, 已選課人數 , 餘額 , 時間, 教室, 備註, 限選條件, 業界專家參與, 屬性碼, 跨領域學分學程, Moocs]
# Index: []
#
# [0 rows x 24 columns]

# %%
columns = []
for column in df_courses.columns:
    columns.append(column.replace("(","").replace("*","").replace(":","").replace(")","").replace("連結課程地圖","").replace("主負責老師","").replace(" ",""))

# %%
df_courses.columns = columns

# %%
def aaa(item):
    return str(item)
df_courses = df_courses.apply(aaa)
# Out:
# 系所名稱            0     化學所 CHEM\n1     化學所 CHEM\n2     化學所 CHEM...
# 系號              0     L3\n1     L3\n2     L3\n3     L3\n4     ...
# 序號              0     001\n1     002\n2     005\n3     013\n4 ...
# 課程碼             0     L350420\n1     L350420\n2     L360100\n3...
# 分班碼             0        1\n1        2\n2        1\n3     None...
# 班別              0     碩一\n1     碩一\n2      碩\n3     碩博\n4     ...
# 年級              0     None\n1     None\n2     None\n3     None...
# 類別              0     講義\n1     講義\n2     講義\n3     講義\n4     ...
# 組別              0     None\n1     None\n2     None\n3     None...
# 英語授課            0        N\n1        N\n2        N\n3        N...
# 課程名稱(連結課程地圖)    0          書報討論（二）\n1          書報討論（二）\n2     ...
# 選必修             0      必修\n1      必修\n2      必修\n3      選修\n4 ...
# 學分              0      1\n1      1\n2      0\n3      3\n4     ...
# 教師姓名*:主負責老師     0                         吳欣倫\n1              ...
# 已選課人數           0        23\n1        24\n2       110\n3      ...
# 餘額              0      33\n1      32\n2      68\n3      43\n4 ...
# 時間              0           [2]5\n1           [1]5\n2         ...
# 教室              0      理化大樓 35306\n1      理化大樓 35306\n2     理化...
# 備註              0     None\n1     None\n2      限碩班\n3     None...
# 限選條件            0     None\n1     None\n2     None\n3     None...
# 業界專家參與          0          否\n1          否\n2          否\n3   ...
# 屬性碼             0     CHEM7095\n1     CHEM7095\n2     CHEM7097...
# 跨領域學分學程         0        None\n1        None\n2        None\n3...
# Moocs           0         否\n1         否\n2         否\n3      ...
# dtype: object

# %%
def tostr(item):
    return str(item).replace(" ","")
df_courses.xs(0).apply(tostr)
# Out:
# 系所名稱              化學所CHEM
# 系號                     L3
# 序號                    001
# 課程碼               L350420
# 分班碼                     1
# 班別                     碩一
# 年級                   None
# 類別                     講義
# 組別                   None
# 英語授課                    N
# 課程名稱(連結課程地圖)      書報討論（二）
# 選必修                    必修
# 學分                      1
# 教師姓名*:主負責老師           吳欣倫
# 已選課人數                  23
# 餘額                     33
# 時間                   [2]5
# 教室              理化大樓35306
# 備註                   None
# 限選條件                 None
# 業界專家參與                  否
# 屬性碼              CHEM7095
# 跨領域學分學程              None
# Moocs                   否
# Name: 0, dtype: object

# %%
type(df_courses)
# Out:
# pandas.core.frame.DataFrame
